# %%
for data in [12,13,56,"class","fruit"]:
    print (data)
# Out:
# 12
# 13
# 56
# class
# fruit

# %%
c=0
while c<=50:
    print(c)
    c=c+5
# Out:
# 0
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50
